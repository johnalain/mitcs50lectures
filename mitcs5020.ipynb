# %% [markdown]
# https://youtu.be/-wyc5FwzkcM lecture 20 mit ana

# %% [markdown]
# https://archive.org/details/mit6_100lf22  lecture20

# %% [markdown]
# https://ocw.mit.edu/courses/6-100l-introduction-to-cs-and-programming-using-python-fall-2022/pages/lecture-20-fitness-tracker-object-oriented-programming-example/  link to lesson20 anna

# %% [markdown]
# https://ocw.mit.edu/courses/6-100l-introduction-to-cs-and-programming-using-python-fall-2022/pages/material-by-lecture/  all lectures

# %% [markdown]
# # generic نوعي  specific محدد  swimming pace وتيرة السباحة

# %%
# define a sample class
class SimpleWorkout(object):
	# class variable
	cal_per_hour = 200
	#constructor special method to create instance
	def __init__(self,start,end,calories=None):# default to None if not passed
		# self variable to refer to an instance of the class
		self.start= start
		self.end= end#parsing=تحليل
		self.calories=calories
		# python string can contain emoji
		self.icon = '😍'
		self.kind = 'workout'
	def get_calories(self):
		return self.calories
	def get_start(self):
		return self.start
	def get_end(self):
		return self.end
	def set_calories(self,calories):
		self.calories = calories
	def set_start(self,start):
		self.start = start
	def set_end(self,end):
		self.end = end
# getters and setters used outside the class to access data attributes

print(SimpleWorkout.__dict__.keys())
print()
#output:
# dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start', 
# 'set_end', '__dict__', '__weakref__', '__doc__'])
my_workout = SimpleWorkout('9/30/2021 1:35 PM','/30/2021 1:51 PM',200)
#access data attribute by dot notation my_workout.calories it is not recommended better 
# access attributes by method my_workout.get_calories
print(my_workout.__dict__.keys)
print(my_workout.__dict__.values)
#dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start',
#  'set_end', '__dict__', '__weakref__', '__doc__'])
# Out:
# dict_keys(['__module__', 'cal_per_hour', '__init__', 'get_calories', 'get_start', 'get_end', 'set_calories', 'set_start', 'set_end', '__dict__', '__weakref__', '__doc__'])
#
# <built-in method keys of dict object at 0x10c6637c0>
# <built-in method values of dict object at 0x10c6637c0>

# %%
# define a sample class
from dateutil import parser
class Workout(object):
	# class variable
	cal_per_hour = 200
	#constructor special method to create instance
	def __init__(self,start,end,calories=None):# default to None if not passed
		# self variable to refer to an instance of the class
		self.start= parser.parse(start)
		self.end= parser.parse(end)#parsing=تحليل
		self.calories=calories
		# python string can contain emoji
		self.icon = '😍'
		self.kind = 'workout'
	def get_calories(self):
		if (self.calories == None):
			return Workout.cal_per_hour*(self.end - self.start).total_seconds()/3600
		else:
			return self.calories
	def get_start(self):
		return self.start
	def get_end(self):
		return self.end
	def set_calories(self,calories):
		self.calories = calories
	def set_start(self,start):
		self.start = start
	def set_end(self,end):
		self.end = end
# getters and setters used outside the class to access data attributes

print(Workout.__dict__.keys())
print()
#output:
# dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start', 
# 'set_end', '__dict__', '__weakref__', '__doc__'])
my_workout = Workout('9/30/2021 1:35 PM','/30/2021 1:51 PM',200)
#access data attribute by dot notation my_workout.calories it is not recommended better 
# access attributes by method my_workout.get_calories
print(my_workout.__dict__.keys)
print(my_workout.__dict__.values)
#dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start',
#  'set_end', '__dict__', '__weakref__', '__doc__'])

# %%
# date & time library has a parser
# fom any format of string date to pure date object
from dateutil import parser
start=parser.parse('Sept 30 2021 1:35 PM')
end = parser.parse('September, 30, 2021 1:45 PM')
print(end-start)
# Out:
# 0:10:00

# %%
# define a sample class
from dateutil import parser
class Workout(object):
	# class variable
	cal_per_hour = 350
	#constructor special method to create instance
	def __init__(self,start,end,calories=None):# default to None if not passed
		# self variable to refer to an instance of the class
		self.start= parser.parse(start)
		self.end= parser.parse(end)#parsing=تحليل
		self.calories=calories
		# python string can contain emoji
		self.icon = '😍'
		self.kind = 'workout'
	def get_calories(self):
		if self.calories == None:
			return Workout.cal_per_hour * (self.end - self.start).total_seconds() / 3600
		else:
			return self.calories
	def get_start(self):
		return self.start
	def get_end(self):
		return self.end
	def set_calories(self,calories):
		self.calories = calories
	def set_start(self,start):
		self.start = start
	def set_end(self,end):
		self.end = end
# getters and setters used outside the class to access data attributes

print(Workout.__dict__.keys())
print()
#output:
# dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start', 
# 'set_end', '__dict__', '__weakref__', '__doc__'])
# my_workout = Workout('9/30/2021 1:35 PM','/30/2021 1:51 PM',200)
#access data attribute by dot notation my_workout.calories it is not recommended better 
# access attributes by method my_workout.get_calories
# print(my_workout.__dict__.keys)
# print(my_workout.__dict__.values)
#dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start',
#  'set_end', '__dict__', '__weakref__', '__doc__'])
# self.cal_per_hour = 250
w_one = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM')

print(w_one.get_calories())
w_two = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM',300)

print(w_two.get_calories())
# Out:
# dict_keys(['__module__', 'cal_per_hour', '__init__', 'get_calories', 'get_start', 'get_end', 'set_calories', 'set_start', 'set_end', '__dict__', '__weakref__', '__doc__'])
#
# 145.83333333333334
# 300

# %%
# define a sample class
from dateutil import parser
class Workout(object):
	# class variable
	cal_per_hour = 350
	#constructor special method to create instance
	def __init__(self,start,end,calories=None):# default to None if not passed
		# self variable to refer to an instance of the class
		self.start= parser.parse(start)
		self.end= parser.parse(end)#parsing=تحليل
		self.calories=calories
		# python string can contain emoji
		self.icon = '😍'
		self.kind = 'workout'
	def get_calories(self):
		if self.calories == None:
			return Workout.cal_per_hour * (self.end - self.start).total_seconds() / 3600
		else:
			return self.calories
	def get_start(self):
		return self.start
	def get_end(self):
		return self.end
	def set_calories(self,calories):
		self.calories = calories
	def set_start(self,start):
		self.start = start
	def set_end(self,end):
		self.end = end
	
def __str__(self):
        """Return a text-based graphical depiction of the workout"""
        width = 16
        retstr =  f"|{'–'*width}|\n"
        retstr += f"|{' ' *width}|\n"
        retstr += f"| {self.icon}{' '*(width-3)}|\n"  #assume width of icon is 2 chars - len('🏃🏽‍♀️');  doesn't do what you'd epxect
        retstr += f"| {self.kind}{' '*(width-len(self.kind)-1)}|\n"
        retstr += f"|{' ' *width}|\n"
        duration_str = str(self.get_duration())
        retstr += f"| {duration_str}{' '*(width-len(duration_str)-1)}|\n"
        cal_str = f"{round(self.get_calories(),1)}"
        retstr += f"| {cal_str} Calories {' '*(width-len(cal_str)-11)}|\n"

        retstr += f"|{' ' *width}|\n"
        retstr +=  f"|{'_'*width}|\n"

        return retstr

# getters and setters used outside the class to access data attributes

print(Workout.__dict__.keys())
print()
#output:
# dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start', 
# 'set_end', '__dict__', '__weakref__', '__doc__'])
# my_workout = Workout('9/30/2021 1:35 PM','/30/2021 1:51 PM',200)
#access data attribute by dot notation my_workout.calories it is not recommended better 
# access attributes by method my_workout.get_calories
# print(my_workout.__dict__.keys)
# print(my_workout.__dict__.values)
#dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start',
#  'set_end', '__dict__', '__weakref__', '__doc__'])
# self.cal_per_hour = 250
w_one = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM')

print(w_one.get_calories())
w_two = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM',300)

print(w_two.get_calories())


class RunWorkout(Workout):
	def __init__(self,start,end,elev=0,calories=None):
		super().__init__(start,end,calories)#parent accessed via super() function
		self.icon='🤣'
		# these replace override pparents default
		self.kind = 'running'
		self.elev = elev
	def get_elev(self):
		return self.elev
	def set_elev(self,e):
		self.elev=e # add new elev
	def __eq__(self,other):
		"""Returns true if this workout is equal to another workout, false o.w."""
		return super().__eq__(other) and self.elev == other.elev
# print(self.icon)

# %%
# define a sample class
from dateutil import parser
class Workout(object):
	# class variable
	cal_per_hour = 350
	#constructor special method to create instance
	def __init__(self,start,end,calories=None):# default to None if not passed
		# self variable to refer to an instance of the class
		self.start= parser.parse(start)
		self.end= parser.parse(end)#parsing=تحليل
		self.calories=calories
		# python string can contain emoji
		self.icon = '😍'
		self.kind = 'workout'
	def get_calories(self):
		if self.calories == None:
			return Workout.cal_per_hour * (self.end - self.start).total_seconds() / 3600
		else:
			return self.calories
	def get_start(self):
		return self.start
	def get_end(self):
		return self.end
	def set_calories(self,calories):
		self.calories = calories
	def set_start(self,start):
		self.start = start
	def set_end(self,end):
		self.end = end

def __str__(self):
        """Return a text-based graphical depiction of the workout"""
        width = 16
        retstr =  f"|{'–'*width}|\n"
        retstr += f"|{' ' *width}|\n"
        retstr += f"| {self.icon}{' '*(width-3)}|\n"  #assume width of icon is 2 chars - len('🏃🏽‍♀️');  doesn't do what you'd epxect
        retstr += f"| {self.kind}{' '*(width-len(self.kind)-1)}|\n"
        retstr += f"|{' ' *width}|\n"
        duration_str = str(self.get_duration())
        retstr += f"| {duration_str}{' '*(width-len(duration_str)-1)}|\n"
        cal_str = f"{round(self.get_calories(),1)}"
        retstr += f"| {cal_str} Calories {' '*(width-len(cal_str)-11)}|\n"

        retstr += f"|{' ' *width}|\n"
        retstr +=  f"|{'_'*width}|\n"

        return retstr
w = Workout(self.start,self.end,300)


# getters and setters used outside the class to access data attributes

# print(Workout.__dict__.keys())
# print()
#output:
# dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start', 
# 'set_end', '__dict__', '__weakref__', '__doc__'])
# my_workout = Workout('9/30/2021 1:35 PM','/30/2021 1:51 PM',200)
#access data attribute by dot notation my_workout.calories it is not recommended better 
# access attributes by method my_workout.get_calories
# print(my_workout.__dict__.keys)
# print(my_workout.__dict__.values)
#dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start',
#  'set_end', '__dict__', '__weakref__', '__doc__'])
# self.cal_per_hour = 250
w_one = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM')

print(w_one.get_calories())
w_two = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM',300)

print(w_two.get_calories())
# Out:
# dict_keys(['__module__', 'cal_per_hour', '__init__', 'get_calories', 'get_start', 'get_end', 'set_calories', 'set_start', 'set_end', '__dict__', '__weakref__', '__doc__'])
#
# 145.83333333333334
# 300

# %%
# define a sample class
from dateutil import parser
class Workout(object):
	# class variable
	cals_per_hr = 350
	#constructor special method to create instance
	def __init__(self,start,end,calories=None):# default to None if not passed
		# self variable to refer to an instance of the class
		self.start= parser.parse(start)
		self.end= parser.parse(end)#parsing=تحليل
		self.calories=calories
		# python string can contain emoji
		self.icon = '😍'
		self.kind = 'workout'
	def get_calories(self):
		if self.calories == None:
			return Workout.cals_per_hr * (self.end - self.start).total_seconds() / 3600
		else:
			return self.calories
	def get_start(self):
		return self.start
	def get_end(self):
		return self.end
	def set_calories(self,calories):
		self.calories = calories
	def set_start(self,start):
		self.start = start
	def set_end(self,end):
		self.end = end
	
def __str__(self):
        """Return a text-based graphical depiction of the workout"""
        width = 16
        retstr =  f"|{'–'*width}|\n"
        retstr += f"|{' ' *width}|\n"
        retstr += f"| {self.icon}{' '*(width-3)}|\n"  #assume width of icon is 2 chars - len('🏃🏽‍♀️');  doesn't do what you'd epxect
        retstr += f"| {self.kind}{' '*(width-len(self.kind)-1)}|\n"
        retstr += f"|{' ' *width}|\n"
        duration_str = str(self.get_duration())
        retstr += f"| {duration_str}{' '*(width-len(duration_str)-1)}|\n"
        cal_str = f"{round(self.get_calories(),1)}"
        retstr += f"| {cal_str} Calories {' '*(width-len(cal_str)-11)}|\n"

        retstr += f"|{' ' *width}|\n"
        retstr +=  f"|{'_'*width}|\n"

        return retstr

# getters and setters used outside the class to access data attributes

print(Workout.__dict__.keys())
print()
#output:
# dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start', 
# 'set_end', '__dict__', '__weakref__', '__doc__'])
# my_workout = Workout('9/30/2021 1:35 PM','/30/2021 1:51 PM',200)
#access data attribute by dot notation my_workout.calories it is not recommended better 
# access attributes by method my_workout.get_calories
# print(my_workout.__dict__.keys)
# print(my_workout.__dict__.values)
#dict_keys(['__module__', '__init__', 'get_calories',
#  'get_start', 'get_end', 'set_calories', 'set_start',
#  'set_end', '__dict__', '__weakref__', '__doc__'])
# self.cal_per_hour = 250
w_one = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM')

print(w_one.get_calories())
w_two = Workout('Jan 1 2021 3:35 PM','Jan 1 2021 4:00 PM',300)

print(w_two.get_calories())


class RunWorkout(Workout):
	def __init__(self,start,end,elev=0,calories=None):
		super().__init__(start,end,calories)#parent accessed via super() function
		self.icon='🤣'
		# these replace override pparents default
		self.kind = 'running'
		self.elev = elev
	def get_elev(self):
		return self.elev
	def set_elev(self,e):
		self.elev=e # add new elev
	def get_calories(self):
			"""Return the total calories consumed by the workout, derived
			using 1) the GPS points if supplied, 2) calories, if supplied,
			or 3) an estimate of the calories based on the duration"""
			if (self.route_gps_points != None):
				dist = 0
				lastP = self.route_gps_points[0]
				for p in self.route_gps_points[1:]:
					dist += gpsDistance(lastP,p)
					lastP = p
				return dist * RunWorkout.cals_per_km
			else:
				return super().get_calories()
	def __eq__(self,other):
		"""Returns true if this workout is equal to another workout, false o.w."""
		return super().__eq__(other) and self.elev == other.elev
class SwimWorkout(Workout):
    """Subclass of workout to representing swimming"""
    
    # redefine class variable cal_per_hr
    cal_per_hr = 400
    
    def __init__(self, start, end, pace, calories=None):
        """Create a new instance of a swimming workout, where start and
        end are strings representing the start and end time of the workout,
        and pace is the pace of the workout in min/100yd, and calories
        is an optional parameter specifying the calories burned in the workout
        """
        super().__init__(start,end,calories)
        self.icon = '🏊‍'
        self.kind = 'Swimming'
        self.pace = pace
    def get_pace(self):
        """Return the pace of the workout"""
        return self.pace
    def get_calories(self):
        """Return the total calories burned in the swim workout
           using the SwimWorkout cal_per_hr class variable"""
        if (self.calories == None):
            # calc the calories based on the length of the workout and cal_per_hr
            return SwimWorkout.cal_per_hr * (self.end - self.start).total_seconds() / 3600.0
        else:
            return self.calories
# print(self.icon)

w = Workout('9/30/2021 1:35 PM','9/30/2021 1:57 PM') # uses 200 cal_per_hr
r = RunWorkout('9/30/2021 1:35 PM','9/30/2021 3:57 PM', 100) # uses 200 cal_per_hr
sw = SwimWorkout('9/30/2021 1:35 PM','9/30/2021 1:57 PM', 100) # uses 400 cal_per_hr
print(w)
print(r)
print(sw)

# %% [markdown]
# https://youtu.be/-wyc5FwzkcM?t=3300
