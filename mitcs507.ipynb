# %% [markdown]
# https://youtu.be/Qf6OVR8MLnU lecture 7 mit

# %%
def is_even(i):
	if (i>0 and i%2==0):
			return True
	else:
		return False
is_even(6)
# Out:
# True

# %%
def div_by(n,d):
	if  n%d ==0:
		return True
	else:
		return False
print(div_by(10,3))
print(div_by(195,13))
# Out:
# False
# True

# %%
def is_even(i):
        print("inside is even")
        return i % 2 == 0
a = is_even(4)
b = is_even(10)
c = is_even(123456)
print(a, b, c)
# Out:
# inside is even
# inside is even
# inside is even
# True True True

# %%
for i in range(1, 10):
	if is_even(i):
			print(i,'even')
	else:
		print(i,'odd')
# Out:
# inside is even
# 1 odd
# inside is even
# 2 even
# inside is even
# 3 odd
# inside is even
# 4 even
# inside is even
# 5 odd
# inside is even
# 6 even
# inside is even
# 7 odd
# inside is even
# 8 even
# inside is even
# 9 odd

# %%
def sum_odd(a,b):
        sum_of_odds = 0
        for i in range(a, b+1):
                if i %2 == 0:
                        sum_of_odds += i
                        print(i,sum_of_odds)
        return sum_of_odds
print(sum_odd(2,4))
# Out:
# 2 2
# 4 6
# 6

# %%
def sum_odd(a,b):
        sum_of_odds = 0
        for i in range(a, b+1):
                if i%2 == 1:
                        sum_of_odds += i
        return sum_of_odds
print(sum_odd(2,7))
# Out:
# 15

# %%
def sum_odd(a,b):
        sum_of_odds = 0
        i = a
        while i<=b:
                if i%2 ==1:
                        sum_of_odds+= i
                i += 1
        return sum_of_odds
print(sum_odd(2,7))
# Out:
# 15
