# %% [markdown]
# https://youtu.be/xAcTmDO6NTI

# %%
type(5)
type(3.0)
# Out:
# float

# %%
float(3)
int(3.9)
round(3.9)
# Out:
# 4

# %%
print(3 + 2)
(4+2)*6-1
# Out:
# 5
# 35

# %%
type((4+2)*6-1)
float((4+2)*6-1)
# Out:
# 35.0

# %%
pi = 355/113
print(pi)
# Out:
# 3.1415929203539825

# %%
pi = 355/113
radius = 2.2
area = pi*(radius**2)
circonference = pi*(radius*2)
print(area)
print(circonference)
# Out:
# 15.205309734513278
# 13.823008849557525
