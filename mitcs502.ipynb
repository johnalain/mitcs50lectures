# %% [markdown]
# https://youtu.be/lzYrMcI92kw?t=18  iteration

# %% [markdown]
# https://youtu.be/lzYrMcI92kw?t=257

# %%
where = input("You're in the lost forest. Go left or right? ")

while where == "right":
    where = input("You're still in the forest. Go left or right? ")

print("You are out of the lost forest!")
# Out:
# You are out of the lost forest!

# %%
n = int(input("please enter a non negative number: "))
while n > 0: 
        print('x')
        n = n - 1
# Out:
# x
# x
# x
# x
# x

# %% [markdown]
# https://youtu.be/lzYrMcI92kw?t=1066

# %%
n = 0
where = input("go left or right")
while where == 'right':
	n = n+1
	if n>2:
		print(":)")
	where = input("go left or right ")
print("go out")
# Out:
# :)
# go out

# %%
print("rita josephine")
# Out:
# rita josephine

# %%
x = 6
i = 1
factorial = 1
while i <= x:
        factorial *= i
        i += 1
print(f'{x} factorial is {factorial}')
# Out:
# 6 factorial is 720

# %%
for n in range(5):
        print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for me in range(4,0,-1):
        print("$"*me)
# Out:
# $$$$
# $$$
# $$
# $

# %%
mysum = 0
for i in range(10):
        mysum += i
print(mysum)
# Out:
# 45

# %%
mysum = 0
start = 3
end = 5
for i in range(start, end):
        print(i)
        mysum +=i
print(mysum)
# Out:
# 3
# 4
# 7

# %%
mysum = 0
start = 3
end = 5
for i in range(start, end+1):
        print('i=',i)
        mysum +=i
print(mysum)
# Out:
# i= 3
# i= 4
# i= 5
# 12
