# %% [markdown]
# https://youtu.be/UdEX0E9lIQM

# %% [markdown]
# operating on strings are concatenate and repeat

# %%
a = 'myself'
b = 'is michel'
silly = 'a' + ' ' + 'b'

# %%
silly
# Out:
# 'a b'

# %%
z = a * 5

# %%
z
# Out:
# 'myselfmyselfmyselfmyselfmyself'

# %%
b = ":"
c = ")"
s1 = b + 2 * c

# %%
s1
# Out:
# ':))'

# %%
f =  "a "
g =  " b"
h = "3"
s2 = (f+g)*int(h)

# %%
s2
# Out:
# 'a  ba  ba  b'

# %%
s = "ABC d3f ghi"
s[3:len(s)-1]
s[4:0:-1]
# Out:
# 'd CB'

# %%
s[3:len(s)-1]
# Out:
# ' d3f gh'

# %%
s1 = "car"
s1[0]= 'b'#gives erroe
s1 = 'b'+s[1:len(s)]#allowed s1 bound to new object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 s1 = "car"
# ----> 2 s1[0]= 'b'
#       3 s1 = 'b'+s[1:len(s)]
#
# TypeError: 'str' object does not support item assignment

# %%
s1
# Out:
# 'car'

# %%
a = "the"
b = 3
c = "musketeers"
print(a,b,c)
print(a + " " +str(b)+" " + c)
print(a +b+ c)# gives an error
# Out:
# the 3 musketeers
# the 3 musketeers
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       4 print(a,b,c)
#       5 print(a + " " +str(b)+" " + c)
# ----> 6 print(a +b+ c)# gives an error
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# https://youtu.be/UdEX0E9lIQM?t=2253

# %%
num1 = int(input("enter num1"))
print(5 * num1)
# Out:
# 20

# %%
num2 = input("enter num1")
print(5*num2)
# Out:
# 44444

# %%
question = input("choose a verb")
print("i can", question, 'better than you')
print( (question+ ' ')*5)
# Out:
# i can run better than you
# run run run run run

# %%
x = int(input("what is x to find the cube root of? "))
g = float(input("what guess to start with? "))
print("current estimated cube = ",g**3)
next_g =g - ((g**3 - x) / (3* g**2))
print('next guess to try = ', next_g)
# Out:
# current estimated cube =  27.21561387081064
# next guess to try =  3.000021070009142

# %% [markdown]
# https://youtu.be/UdEX0E9lIQM?t=2658

# %%
num = 3000
fraction = 1/3
print(num*fraction, 'is', fraction*100,'% of',num)
print(num*fraction,'is',str(fraction*100) + '% of',num)
print(f'{num*fraction} is {fraction*100} % of{num}')
# Out:
# 1000.0 is 33.33333333333333 % of 3000
# 1000.0 is 33.33333333333333% of 3000
# 1000.0 is 33.33333333333333 % of3000

# %% [markdown]
# https://youtu.be/UdEX0E9lIQM?t=3078

# %%
pset_time = 15
sleep_time = 8
print(sleep_time>pset_time)
derive = True
drink = False
both = drink and derive
print(both)
# Out:
# False
# False

# %%
secret = 5
guess = int(input("please guess a  number: "))
equal=(guess == secret)
print(equal)
# if guess > secret:
#         print ("ok")
# elif guess< secret:
#         guess = int(input("please guess a  number: "))
# else:
        # print(" not ok")
# Out:
# True

# %%
pset_time = 12
sleep_time = 2
if(pset_time + sleep_time)>24:
        print('impossible')
elif (pset_time + sleep_time)>=24:
        print("full schedule")
else:
        leftover = abs(24-pset_time-sleep_time)
        print(leftover ,"hour of free time: ")
print("end of day")
# Out:
# 10 hour of free time:
# end of day
